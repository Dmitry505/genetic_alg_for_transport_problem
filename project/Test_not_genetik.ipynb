# %%
import os
import numpy as np
from New_analog_pizza import solve_transportation_problem as optimize
from New_analog_pizza import output_data as output
from reader import read_transportation_data as read


dir_list = os.listdir('test_data')

# %%
for i, obj in enumerate(dir_list):
    num_factories, num_stores, production, demand, costs, fixed_costs = read(f'test_data/{obj}')
    result = optimize(production, demand, costs, fixed_costs)
    print(f"Тест номер: {i + 1}\n")
    print(f"Тестовый файл {obj}")
    output(production, demand, costs, fixed_costs)
    print("\n\n")
# Out:
# Тест номер: 1
#
# Тестовый файл data_1.txt
# Общее время выполнения: 0.0 секунд
# Общие затраты: 2078
# Решение:
# Поставщик 1 -> Потребитель 0: Объем перевозки 146, Затраты 584
# Поставщик 0 -> Потребитель 1: Объем перевозки 142, Затраты 1420
#
#
#
# Тест номер: 2
#
# Тестовый файл data_10.txt
# Общее время выполнения: 0.0 секунд
# Общие затраты: 1711
# Решение:
# Поставщик 0 -> Потребитель 2: Объем перевозки 81, Затраты 162
# Поставщик 2 -> Потребитель 1: Объем перевозки 102, Затраты 816
# Поставщик 2 -> Потребитель 0: Объем перевозки 34, Затраты 68
# Поставщик 3 -> Потребитель 0: Объем перевозки 61, Затраты 122
# Поставщик 1 -> Потребитель 3: Объем перевозки 86, Затраты 344
#
#
#
# Тест номер: 3
#
# Тестовый файл data_11.txt
# Общее время выполнения: 0.0 секунд
# Общие затраты: 2281
# Решение:
# Поставщик 3 -> Потребитель 2: Объем перевозки 114, Затраты 342
# Поставщик 2 -> Потребитель 0: Объем перевозки 116, Затраты 580
# ...
